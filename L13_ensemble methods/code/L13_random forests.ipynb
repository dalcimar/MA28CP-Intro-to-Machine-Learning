# %% [markdown]
# # L13 - Ensemble methodos (Random Forests)
#
# ---
#
#
# - Instructor: Dalcimar Casanova (dalcimar@gmail.com)
# - Course website: https://www.dalcimar.com/disciplinas/aprendizado-de-maquina
# - Bibliography: based on lectures of Dr. Sebastian Raschka

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
iris = datasets.load_iris()
X = iris.data[:,:]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)

rfc = RandomForestClassifier(n_estimators=100, max_features="log2", bootstrap=True, oob_score=True)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc.oob_score_
# Out:
# 0.9375

# %%
y_test_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pred)
# Out:
# 0.9736842105263158
